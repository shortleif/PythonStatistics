# %% [markdown]
# # Data Analysis Starter

# %%
# %pip install numpy pandas scipy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ds_utils import StatsHelper, calculate_confidence_interval

# Load your data here
data = [22, 24, 25, 30, 32, 50, 21, 23, 24]

# Initialize the companion helper
helper = StatsHelper(data)
print(f"Summary: {helper.get_summary()}")
print(f"Distribution Type: {helper.check_normality()}")
